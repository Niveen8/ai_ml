# %% [markdown]
# # # Day 3 :

# %%
import numpy as np
data = np.array([10, 12, 12, 13, 100])
print(np.mean(data))
print(np.median(data))
# Out:
# 29.4
# 12.0

# %%
import numpy as np
data = np.array([100, 110, 120, 130, 10])
print(np.mean(data))
print(np.median(data))
# Out:
# 94.0
# 110.0

# %%
import numpy as np
v = np.array([25, 50000, 3])

# %%
print(v)
# Out:
# [   25 50000     3]

# %%
print(v.shape)
# Out:
# (3,)

# %%
import numpy as np

n = np.array([21, 88, 3])

print(n)
# Out:
# [21 88  3]

# %%
X = np.array([[25, 50000, 3],[40, 80000, 10],[33, 62000, 5]])
print(X.shape)
# Out:
# (3, 3)

# %%
X = np.array([[2, 3],[4,0],[3,8]])
print(X.shape)
# Out:
# (3, 2)

# %%
features = np.array([25, 50000, 3])
weights = np.array([0.1, 0.0002, 1.5])
prediction = np.dot(features, weights)

# %%
print(prediction)
# Out:
# 17.0

# %%
features = np.array([5, 8, 90])

weights = np.array([2, 1.5, 0.1])

prediction = np.dot(features, weights)

print(prediction)
# Out:
# 31.0

# %%
X = np.array([[25, 50000, 3], [40, 80000, 10]])
w = np.array([0.1, 0.0002, 1.5]) 
predictions = X @ w

# %%
print(predictions)
# Out:
# [17. 35.]

# %%
X = np.array([[5, 8, 90],[4, 6, 80],[7, 9, 95]])
w = np.array([2, 1.5, 0.1])
predictions = X @ w
print(predictions)
# Out:
# [31. 25. 37.]

# %%
X = np.array([[7,0],[4,0]])
w = np.array([2,5])
predictions = X @ w
print(predictions)
# Out:
# [14  8]

# %%
import numpy as np

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])
print("Vector v1: ", v1)
print("Vector v2: ", v2)
# Out:
# Vector v1:  [1 2 3]
# Vector v2:  [4 5 6]

# %%
v_add = v1 + v2
print(v_add)
# Out:
# [5 7 9]

# %%
dot_v = np.dot(v1,v2)
print(dot_v)
# Out:
# 32

# %%
norm_v1 = np.linalg.norm(v1)
print(norm_v1)
# Out:
# 3.7416573867739413

# %%
norm_v2 = np.linalg.norm(v2)
print(norm_v2)
# Out:
# 8.774964387392123

# %%
A =  np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7,81]])
print("Matrix A:\n", A)
print("Matrix B:\n", B)
# Out:
# Matrix A:
#  [[1 2]
#  [3 4]]
# Matrix B:
#  [[ 5  6]
#  [ 7 81]]

# %%
matrix_add = A + B
print(matrix_add)
# Out:
# [[ 6  8]
#  [10 85]]

# %%
element_wise_mul = A * B
dot_product_matrix= np.dot(A, B)
print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("Element-wise multiplication (AB):\n", element_wise_mul)
print("Dot product of matrices (A, B):\n", dot_product_matrix)
# Out:
# Matrix A:
#  [[1 2]
#  [3 4]]
# Matrix B:
#  [[ 5  6]
#  [ 7 81]]
# Element-wise multiplication (AB):
#  [[  5  12]
#  [ 21 324]]
# Dot product of matrices (A, B):
#  [[ 19 168]
#  [ 43 342]]

# %%
def matrix_multiplication(matrix1, matrix2):
    
    rows_matrix1 = len(matrix1)
    cols_matrix1 = len(matrix1[0])

    rows_matrix2 = len(matrix2)
    cols_matrix2 = len(matrix2[0])
    if cols_matrix1 != rows_matrix2:
        raise ValueError("Number of columns in Matrix1 must be equal to number of rows in Matrix2")
    result = [[0 for _ in range(cols_matrix2)] for _ in range(rows_matrix1)]
    for i in range(rows_matrix1):
        for j in range(cols_matrix2):
            for k in range(cols_matrix1):
                result[i][j] += matrix1[i][k] * matrix2[k][j]

    return result
    print(result)
