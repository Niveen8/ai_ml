# %% [markdown]
# # Day 1  AI_ML Environment
#  my Python environment

# %%
print("Hello python")
# Out:
# Hello python

# %%
age = 21
has_card = True

if age >= 20 and has_card:
    print("Allowed")
else:
    print("Not Allowed")
# Out:
# Allowed
