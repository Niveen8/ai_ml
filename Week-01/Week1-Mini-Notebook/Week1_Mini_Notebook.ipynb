# %% [markdown]
# # # Day 5 — Matplotlib & Week 1 Mini-Notebook

# %% [markdown]
#  Step 1: Load and clean a provided dataset with Pandas (handling any missing values).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")

# %%
columns = [
    "sepal_length",
    "sepal_width",
    "petal_length",
    "petal_width",
    "species"
]

df = pd.read_csv("iris.csv", names=columns)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# Step 2: Use NumPy to compute at least one derived numeric feature or summary statistic.

# %%
import numpy as np

# %%
mean_sepal_length = np.mean(df["sepal_length"])

print( mean_sepal_length)
# Out:
# 5.843333333333334

# %%
print(np.mean(df["sepal_length"]))
# Out:
# 5.843333333333334

# %%
print(np.max(df["sepal_length"]))
# Out:
# 7.9

# %%
print(np.max(df["petal_width"]))
# Out:
# 2.5

# %% [markdown]
#  Step 3: Produce at least three labeled plots (including a histogram and a scatter plot) exploring the data

# %%
plt.figure(figsize=(10,5))

# %%
plt.hist(df["sepal_length"], bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["petal_width"], bins=10)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel("Sepal Length")
# Out:
# Text(0.5, 0, 'Sepal Length')

# %%
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.title("Distribution of Sepal Length")
# Out:
# Text(0.5, 1.0, 'Distribution of Sepal Length')

# %%
plt.figure(figsize=(10,5))

plt.hist(df["sepal_length"], bins=10)

plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal Length")

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.hist(df["petal_width"], bins=10)
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal Length")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(df["sepal_length"], df["petal_length"])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal Length and Petal Length")

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(df["sepal_length"], df["sepal_width"])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Sepal Length and Sepal Width")
plt.show()

# %%
species_counts = df["species"].value_counts()
plt.figure(figsize=(6,4))
plt.bar(species_counts.index, species_counts.values)
plt.xlabel("Species")
plt.ylabel("Count")
plt.title("# of Samples")
plt.show()

# %% [markdown]
# Step 4: Write Markdown cells explaining what each visualization reveals about the data.

# %% [markdown]
# # Visualization Insights
# ## Line Plot
# The line chart indicates the sepal length flux with the data.
# Now you can see how the measurement has changed over the sample.
# ## Scatter Plot
# The scatter plot depicts the sepal length against the petal length.
# Shall we look for some patterns or correlations in these two numbers?
# ## Histogram
# This is a histogram of the sepal length.
# When you want to get a sense of the distribution of your data, or how frequently certain values occur, it’s very useful.
# ## Bar Plot
# The bar plot gives the number of samples per species.
# It is the distribution of types of categorical variables within the data.
